# %%
import pandas as pd
import numpy as np

# %%
mortgage4=pd.read_csv('../try/mortgage_index4.csv', encoding='utf-8')
mortgage4.head()
# Out:
#      연도      전국      서울      대구      경기
# 0  2000  65.126  56.038  54.283  60.354
# 1  2001  65.996  57.105  55.476  61.508
# 2  2002  71.919  66.127  62.556  69.548
# 3  2003  74.386  69.582  65.592  73.108
# 4  2004  77.252  72.422  68.974  77.585

# %%
mortgage4.describe()
# Out:
#                 연도          전국          서울          대구          경기
# count    18.000000   18.000000   18.000000   18.000000   18.000000
# mean   2008.500000   86.318611   83.955944   80.956556   86.274667
# std       5.338539   11.361894   14.300457   15.132161   12.906020
# min    2000.000000   65.126000   56.038000   54.283000   60.354000
# 25%    2004.250000   78.213500   73.610500   70.015250   78.680750
# 50%    2008.500000   89.261500   89.379000   83.411500   90.194500
# 75%    2012.750000   93.196250   92.061750   90.768750   94.929000
# max    2017.000000  104.105000  104.564000  107.407000  103.632000

# %%
mortgage4.set_index('연도',inplace=True)
mortgage4.head()
# Out:
#           전국      서울      대구      경기
# 연도
# 2000  65.126  56.038  54.283  60.354
# 2001  65.996  57.105  55.476  61.508
# 2002  71.919  66.127  62.556  69.548
# 2003  74.386  69.582  65.592  73.108
# 2004  77.252  72.422  68.974  77.585

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib as mpl

mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
ax = mortgage4.plot( title='전국지가지수', figsize=(10, 9), legend=True, fontsize=13)

# %%
ax = mortgage4.plot( title='전국지가지수', figsize=(10, 9), legend=True, fontsize=13)

# %%
mortgage5=pd.read_csv('../try/mortgage_index5.csv', encoding='utf-8')
mortgage5.head()
# Out:
#      연도      전국      서울      대구      경기
# 0  2009  89.543  89.549  83.828  90.619
# 1  2010  90.481  90.022  85.618  91.963
# 2  2011  91.536  90.892  87.297  93.315
# 3  2012  92.411  91.236  89.307  94.284
# 4  2013  93.458  92.337  91.256  95.144

# %%
mortgage5.set_index('연도',inplace=True)
mortgage5.head()
# Out:
#           전국      서울      대구      경기
# 연도
# 2009  89.543  89.549  83.828  90.619
# 2010  90.481  90.022  85.618  91.963
# 2011  91.536  90.892  87.297  93.315
# 2012  92.411  91.236  89.307  94.284
# 2013  93.458  92.337  91.256  95.144

# %%
ax = mortgage5.plot( title='지가지수(2009~2017)', figsize=(10, 9), legend=True, fontsize=10)

# %%
mortgage_indexchange=pd.read_csv('../try/mortgage_indexchange.csv', encoding='utf-8')
mortgage_indexchange.head()
# Out:
#      연도     전국     서울     대구     경기
# 0  2006  5.617  9.171  4.185  5.074
# 1  2007  3.886  5.882  2.911  4.229
# 2  2008 -0.319 -1.001 -0.451 -0.267
# 3  2009  0.955  1.396  0.284  1.217
# 4  2010  1.046  0.527  1.401  1.485

# %%
mortgage_indexchange.set_index('연도',inplace=True)
mortgage_indexchange.head()
# Out:
#          전국     서울     대구     경기
# 연도
# 2006  5.617  9.171  4.185  5.074
# 2007  3.886  5.882  2.911  4.229
# 2008 -0.319 -1.001 -0.451 -0.267
# 2009  0.955  1.396  0.284  1.217
# 2010  1.046  0.527  1.401  1.485

# %%
ax = mortgage_indexchange.plot( title='지수변동률(2009~2017)', figsize=(10, 9), legend=True, fontsize=10)
