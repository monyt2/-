# %%
import pandas as pd
import numpy as np

# %%
Bok_Data=pd.read_csv('../try/BOK_DATA.csv',encoding='utf-8')
Bok_Data.head()
# Out:
#      연도  기준금리
# 0  2000  5.25
# 1  2001  4.00
# 2  2002  4.25
# 3  2003  3.75
# 4  2004  3.25

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

if platform.system()=='Darwin':
    rc('font',family='AppleGothic')
elif platform.system()=='Windows':
    path="c:/Windows/Fonts/malgun.ttf"
    font_name=font_manager.FontProperties(fname=path).get_name()
    rc('font',family=font_name)
else:
    print('Unknown system')

# %%
Bok_Data.set_index('연도',inplace=True)
Bok_Data.head()
# Out:
#       기준금리
# 연도
# 2000  5.25
# 2001  4.00
# 2002  4.25
# 2003  3.75
# 2004  3.25

# %%
ax = Bok_Data.plot( title='기준금리', figsize=(10, 9), legend=True, fontsize=13)

# %%
ax = Bok_Data.plot(kind='barh', title='기준금리', figsize=(16, 8), legend=True, fontsize=13)

# %%
money_supply=pd.read_csv('../try/money supply2.csv',encoding='utf-8')
money_supply.head()
# Out:
#      연도      Lf      M2
# 0  2009  1937.3  1508.6
# 1  2010  2096.5  1639.7
# 2  2011  2208.2  1709.0
# 3  2012  2379.5  1798.6
# 4  2013  2543.2  1885.8

# %%
money_supply.set_index('연도',inplace=True)
money_supply.head()
# Out:
#           Lf      M2
# 연도
# 2009  1937.3  1508.6
# 2010  2096.5  1639.7
# 2011  2208.2  1709.0
# 2012  2379.5  1798.6
# 2013  2543.2  1885.8

# %%
ax = money_supply.plot( title='통화량', figsize=(10, 9), legend=True, fontsize=10)

# %%
money_supply=pd.read_csv('../try/money supply3.csv',encoding='utf-8')
money_supply.head()
# Out:
#      연도     M1  본원통화
# 0  2009  357.3  61.7
# 1  2010  399.4  67.6
# 2  2011  425.7  75.2
# 3  2012  442.0  82.1
# 4  2013  484.1  91.4

# %%
money_supply.set_index('연도',inplace=True)
money_supply.head()
# Out:
#          M1  본원통화
# 연도
# 2009  357.3  61.7
# 2010  399.4  67.6
# 2011  425.7  75.2
# 2012  442.0  82.1
# 2013  484.1  91.4

# %%
ax = money_supply.plot( title='통화량', figsize=(10, 9), legend=True, fontsize=10)

# %%
money_supplyrate=pd.read_csv('../try/money_supplyrate.csv',encoding='utf-8')
money_supplyrate.head()
# Out:
#      연도   Lf    M2    M1  본원통화
# 0  2009  7.9  10.3  16.3  18.1
# 1  2010  8.2   8.7  11.8   9.5
# 2  2011  5.3   4.2   6.6  11.3
# 3  2012  7.8   5.2   3.8   9.2
# 4  2013  6.9   4.8   9.5  11.3

# %%
money_supplyrate.set_index('연도',inplace=True)
money_supplyrate.head()
# Out:
#        Lf    M2    M1  본원통화
# 연도
# 2009  7.9  10.3  16.3  18.1
# 2010  8.2   8.7  11.8   9.5
# 2011  5.3   4.2   6.6  11.3
# 2012  7.8   5.2   3.8   9.2
# 2013  6.9   4.8   9.5  11.3

# %%
ax = money_supplyrate.plot( title='통화량변화', figsize=(10, 9), legend=True, fontsize=10)

# %%
laborprofit=pd.read_csv('../try/laborprofit.csv',encoding='utf-8')
laborprofit.head()
# Out:
#      연도     전국     서울    대구    경기도
# 0  2000   8602  10119  8253   8865
# 1  2001   8964  10616  8481   9126
# 2  2002   9419  11185  8886   9672
# 3  2003   9848  11787  9261   9952
# 4  2004  10493  12493  9711  10554

# %%
laborprofit.set_index('연도',inplace=True)
laborprofit.head()
# Out:
#          전국     서울    대구    경기도
# 연도
# 2000   8602  10119  8253   8865
# 2001   8964  10616  8481   9126
# 2002   9419  11185  8886   9672
# 2003   9848  11787  9261   9952
# 2004  10493  12493  9711  10554

# %%
ax = laborprofit.plot( title='1인당소득', figsize=(10, 9), legend=True, fontsize=10)

# %%
laborprofitrate=pd.read_csv('../try/laborprofitrate2.csv',encoding='utf-8')
laborprofitrate.head()
# Out:
#      연도    전국    서울    대구   경기도
# 0  2001  4.21  4.91  2.76  2.94
# 1  2002  5.08  5.36  4.78  5.98
# 2  2003  4.55  5.38  4.22  2.89
# 3  2004  6.55  5.99  4.86  6.05
# 4  2005  6.72  7.68  7.94  5.94

# %%
laborprofitrate.set_index('연도',inplace=True)
laborprofitrate.head()
# Out:
#         전국    서울    대구   경기도
# 연도
# 2001  4.21  4.91  2.76  2.94
# 2002  5.08  5.36  4.78  5.98
# 2003  4.55  5.38  4.22  2.89
# 2004  6.55  5.99  4.86  6.05
# 2005  6.72  7.68  7.94  5.94

# %%
ax = laborprofitrate.plot( title='1인당소득변화', figsize=(10, 9), legend=True, fontsize=10)

# %%
homecount=pd.read_csv('../try/homecount.csv',encoding='utf-8')
homecount.head()
# Out:
#      연도     건축수
# 0  2000   81058
# 1  2001   97717
# 2  2002  138734
# 3  2003  142108
# 4  2004  117461

# %%
homecount.set_index('연도',inplace=True)
homecount.head()
# Out:
#          건축수
# 연도
# 2000   81058
# 2001   97717
# 2002  138734
# 2003  142108
# 2004  117461

# %%
homecount.describe()
# Out:
#                  건축수
# count      17.000000
# mean   131554.529412
# std     26838.781616
# min     81058.000000
# 25%    117461.000000
# 50%    133271.000000
# 75%    141346.000000
# max    189840.000000

# %%
ax = homecount.plot( title='연도별건축수', figsize=(10, 9), legend=True, fontsize=10)

# %%
homecountrate=pd.read_csv('../try/homecountrate.csv',encoding='utf-8')
homecountrate.head()
# Out:
#      연도   증감율
# 0  2001  20.6
# 1  2002  42.0
# 2  2003   2.4
# 3  2004 -17.3
# 4  2005  -5.1

# %%
homecountrate.set_index('연도',inplace=True)
homecountrate.head()
# Out:
#        증감율
# 연도
# 2001  20.6
# 2002  42.0
# 2003   2.4
# 2004 -17.3
# 2005  -5.1

# %%
ax = homecountrate.plot( title='연도별건축수변화', figsize=(10, 9), legend=True, fontsize=10)

# %%
tradecount=pd.read_csv('../try/tradecount.csv',encoding='utf-8')
tradecount.head()
# Out:
#      연도       전국      서울      경기
# 0  2006  1494935  323392  450757
# 1  2007  1148574  193334  299856
# 2  2008  1179742  183197  275248
# 3  2009  1133637  170962  285130
# 4  2010  1037229  115227  234142

# %%
tradecount.set_index('연도',inplace=True)
tradecount.head()
# Out:
#            전국      서울      경기
# 연도
# 2006  1494935  323392  450757
# 2007  1148574  193334  299856
# 2008  1179742  183197  275248
# 2009  1133637  170962  285130
# 2010  1037229  115227  234142

# %%
ax = tradecount.plot( title='연도별 주택거래량', figsize=(9, 8), legend=True, fontsize=9)
